# %%
import socket

# %%
import socket

targetIp = input("Enter the target IP address: ")
def portscan(port):

    sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    sock.settimeout(1)
    result = sock.connect_ex((targetIp, port))
    sock.close()
    return result
    

if __name__ == "__main__":
    for port in range(1001):
        if 0 == portscan(port):
            print("Port " + str(port) + " is open!")
        
#         else:
#             print("Port " + str(portNumber) + " is closed.")
# Out:
# Enter the target IP address: 192.168.0.1
# Port 53 is open!
# Port 80 is open!
# Port 443 is open!

# %%
sock.connect_ex(("192.168.0.1", 53))
# Out:
# 9

# %%
import socket

    

if __name__ == "__main__":
    for port in range(1, 1025):
        sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
        sock.settimeout(1)


        
        result = sock.connect_ex(("192.168.0.1", 53))

        if 0 == result:
            print("Port: {} Open".format(port))
        sock.close()
# Out:
# Port: 1 Open
# Port: 2 Open
# Port: 3 Open
# Port: 4 Open
# Port: 5 Open
# Port: 6 Open
# Port: 7 Open
# Port: 8 Open
# Port: 9 Open
# Port: 10 Open
# Port: 11 Open
# Port: 12 Open
# Port: 13 Open
# Port: 14 Open
# Port: 15 Open
# Port: 16 Open
# Port: 17 Open
# Port: 19 Open
# Port: 20 Open
# Port: 21 Open
# Port: 22 Open
# Port: 23 Open
# Port: 24 Open
# Port: 25 Open
# Port: 26 Open
# Port: 27 Open
# Port: 29 Open
# Port: 30 Open
# Port: 31 Open
# Port: 32 Open
# Port: 33 Open
# Port: 34 Open
# Port: 35 Open
# Port: 36 Open
# Port: 37 Open
# Port: 38 Open
# Port: 39 Open
# Port: 40 Open
# Port: 41 Open
# Port: 42 Open
# Port: 43 Open
# Port: 44 Open
# Port: 45 Open
# Port: 46 Open
# Port: 47 Open
# Port: 48 Open
# Port: 49 Open
# Port: 50 Open
# Port: 52 Open
# Port: 53 Open
# Port: 54 Open
# Port: 55 Open
# Port: 56 Open
# Port: 57 Open
# Port: 58 Open
# Port: 59 Open
# Port: 60 Open
# Port: 61 Open
# Port: 62 Open
# Port: 63 Open
# Port: 64 Open
# Port: 65 Open
# Port: 66 Open
# Port: 67 Open
# Port: 68 Open
# Port: 69 Open
# Port: 70 Open
# Port: 72 Open
# Port: 73 Open
# Port: 74 Open
# Port: 75 Open
# Port: 76 Open
# Port: 77 Open
# Port: 78 Open
# Port: 79 Open
# Port: 80 Open
# Port: 81 Open
# Port: 82 Open
# Port: 83 Open
# Port: 85 Open
# Port: 86 Open
# Port: 87 Open
# Port: 88 Open
# Port: 89 Open
# Port: 90 Open
# Port: 91 Open
# Port: 92 Open
# Port: 93 Open
# Port: 94 Open
# Port: 95 Open
# Port: 96 Open
# Port: 97 Open
# Port: 98 Open
# Port: 99 Open
# Port: 100 Open
# Port: 101 Open
# Port: 102 Open
# Port: 103 Open
# Port: 104 Open
# Port: 106 Open
# Port: 107 Open
# Port: 108 Open
# Port: 109 Open
# Port: 110 Open
# Port: 111 Open
# Port: 112 Open
# Port: 113 Open
# Port: 114 Open
# Port: 115 Open
# Port: 116 Open
# Port: 117 Open
# Port: 118 Open
# Port: 119 Open
# Port: 120 Open
# Port: 121 Open
# Port: 122 Open
# Port: 123 Open
# Port: 125 Open
# Port: 126 Open
# Port: 127 Open
# Port: 128 Open
# Port: 129 Open
# Port: 130 Open
# Port: 131 Open
# Port: 132 Open
# Port: 133 Open
# Port: 134 Open
# Port: 135 Open
# Port: 137 Open
# Port: 138 Open
# Port: 139 Open
# Port: 140 Open
# Port: 141 Open
# Port: 142 Open
# Port: 143 Open
# Port: 144 Open
# Port: 145 Open
# Port: 146 Open
# Port: 147 Open
# Port: 148 Open
# Port: 149 Open
# Port: 150 Open
# Port: 151 Open
# Port: 153 Open
# Port: 154 Open
# Port: 155 Open
# Port: 156 Open
# Port: 157 Open
# Port: 158 Open
# Port: 159 Open
# Port: 160 Open
# Port: 161 Open
# Port: 162 Open
# Port: 163 Open
# Port: 164 Open
# Port: 165 Open
# Port: 166 Open
# Port: 167 Open
# Port: 168 Open
# Port: 170 Open
# Port: 171 Open
# Port: 172 Open
# Port: 173 Open
# Port: 174 Open
# Port: 175 Open
# Port: 176 Open
# Port: 177 Open
# Port: 178 Open
# Port: 179 Open
# Port: 180 Open
# Port: 181 Open
# Port: 182 Open
# Port: 183 Open
# Port: 184 Open
# Port: 185 Open
# Port: 186 Open
# Port: 187 Open
# Port: 188 Open
# Port: 190 Open
# Port: 191 Open
# Port: 192 Open
# Port: 193 Open
# Port: 194 Open
# Port: 195 Open
# Port: 196 Open
# Port: 197 Open
# Port: 198 Open
# Port: 199 Open
# Port: 200 Open
# Port: 201 Open
# Port: 202 Open
# Port: 203 Open
# Port: 204 Open
# Port: 205 Open
# Port: 206 Open
# Port: 208 Open
# Port: 209 Open
# Port: 210 Open
# Port: 211 Open
# Port: 212 Open
# Port: 213 Open
# Port: 214 Open
# Port: 215 Open
# Port: 216 Open
# Port: 217 Open
# Port: 218 Open
# Port: 219 Open
# Port: 220 Open
# Port: 221 Open
# Port: 222 Open
# Port: 223 Open
# Port: 224 Open
# Port: 225 Open
# Port: 227 Open
# Port: 228 Open
# Port: 229 Open
# Port: 230 Open
# Port: 231 Open
# Port: 232 Open
# Port: 233 Open
# Port: 234 Open
# Port: 235 Open
# Port: 236 Open
# Port: 237 Open
# Port: 238 Open
# Port: 239 Open
# Port: 240 Open
# Port: 241 Open
# Port: 243 Open
# Port: 244 Open
# Port: 245 Open
# Port: 246 Open
# Port: 247 Open
# Port: 248 Open
# Port: 249 Open
# Port: 250 Open
# Port: 251 Open
# Port: 252 Open
# Port: 253 Open
# Port: 254 Open
# Port: 255 Open
# Port: 256 Open
# Port: 257 Open
# Port: 258 Open
# Port: 260 Open
# Port: 261 Open
# Port: 262 Open
# Port: 263 Open
# Port: 264 Open
# Port: 265 Open
# Port: 266 Open
# Port: 267 Open
# Port: 268 Open
# Port: 269 Open
# Port: 270 Open
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-102-74f4579acf4a> in <module>
#      10
#      11
# ---> 12         result = sock.connect_ex(("192.168.0.1", 53))
#      13
#      14         if 0 == result:
#
# KeyboardInterrupt:
